# %% [markdown]
# Daily Challenge: Understanding the Essence of Machine Learning
#
#
# 👩‍🏫 👩🏿‍🏫 What You’ll learn
# The fundamental concepts of Machine Learning (ML) and its importance in data analytics.
# Different types of machine learning: Supervised, Unsupervised, and Reinforcement Learning, and how to identify them.
# The process of a machine learning model, including Feature Selection, Model Selection, and Model Evaluation.
#
#
# 🛠️ What you will create
# A summary document that explains the key aspects of Machine Learning, its types, and the typical process involved in developing a machine learning model.
# A simple flowchart or diagram that visually represents the process of a machine learning model from feature selection to model evaluation.
#
#
# Instructions
# Write a brief summary explaining the basics of Machine Learning and why it is important for data analysts.
# Discuss the applications of Machine Learning across different industries, providing at least three specific examples.
# Create a section in your document that clearly differentiates between Supervised, Unsupervised, and Reinforcement Learning.
# For each type, provide a brief definition and an example scenario where that type of machine learning is typically applied.
# Describe the process of developing a machine learning model. Focus on three main stages: Feature Selection, Model Selection, and Model Evaluation.

# %%
# Understanding the Essence of Machine Learning
# 1. What is Machine Learning?

# Machine Learning (ML) is a branch of Artificial Intelligence that allows computers to learn from data and make predictions without being explicitly programmed.

# Why is it important for Data Analysts?
# Finds patterns in data.
# Helps make predictions.
# Automates data analysis.
# Supports better decision-making.
# 2. Applications of Machine Learning
# Healthcare

# Machine learning helps detect diseases from medical images.

# Finance

# Machine learning helps detect fraudulent transactions.

# E-commerce

# Machine learning recommends products based on customer preferences and purchase history.

# 3. Types of Machine Learning
# Supervised Learning

# Supervised learning uses labeled data, meaning the correct answer is known.

# Example: Predicting whether a customer will repay a loan.

# Unsupervised Learning

# Unsupervised learning uses unlabeled data to find hidden patterns.

# Example: Grouping customers based on their buying behavior.

# Reinforcement Learning

# Reinforcement learning learns through rewards and penalties.

# Example: A robot learning how to navigate a room without hitting obstacles.

# 4. Machine Learning Process
# Feature Selection

# Select the most important variables that will be used to make predictions.

# Example: Age, income, and credit score for loan prediction.

# Model Selection

# Choose the machine learning algorithm that best fits the problem.

# Example: Linear Regression or Decision Tree.

# Model Evaluation

# Measure how well the model performs using evaluation metrics such as accuracy, precision, and recall.

# 5. Simple Flowchart
# Data Collection
#       ↓
# Feature Selection
#       ↓
# Model Selection
#       ↓
# Model Training
#       ↓
# Model Evaluation
#       ↓
# Prediction
# Conclusion

# Machine Learning helps computers learn from data, identify patterns, and make predictions. It is widely used in many industries to improve decision-making and efficiency.
