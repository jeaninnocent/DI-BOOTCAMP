# %%
url_iris = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

# %%
import pandas as pd

# %%
df_iris = pd.read_csv(url_iris)

# %%
print(df_iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %% [markdown]
# Classification et Justification :
#
# sepal_length (longueur du sépale) : Quantitative (Mesure numérique continue en centimètres).
#
# sepal_width (largeur du sépale) : Quantitative (Mesure numérique continue).
#
# petal_length (longueur du pétale) : Quantitative (Mesure numérique continue).
#
# petal_width (largeur du pétale) : Quantitative (Mesure numérique continue).
#
# species (espèce) : Qualitative (Catégorie nominale définissant le type de fleur : setosa, versicolor, virginica).
