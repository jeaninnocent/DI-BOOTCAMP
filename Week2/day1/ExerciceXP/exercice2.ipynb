# %%
import pandas as pd

# %%
df_sleep = pd.read_csv('C:\\Users\\LENOVO\\Desktop\\DI-BOOTCAMP\\Time Americans Spend Sleeping.csv')
df_mental = pd.read_csv('C:\\Users\\LENOVO\\Desktop\\DI-BOOTCAMP\\Mental health Depression disorder Data.csv')
df_credit = pd.read_csv('C:\\Users\\LENOVO\\Desktop\\DI-BOOTCAMP\\crx.csv')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_23268\190529502.py:2: DtypeWarning: Columns (0: Bipolar disorder (%), 1: Eating disorders (%)) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mental = pd.read_csv('C:\\Users\\LENOVO\\Desktop\\DI-BOOTCAMP\\Mental health Depression disorder Data.csv')

# %%
print(df_sleep.head())
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# Descriptions des jeux de données :
#
# Sommeil des Américains : Contient probablement des informations démographiques (âge, profession) croisées avec des habitudes de vie et le nombre d'heures de sommeil par nuit.
#
# Santé Mentale (Tendances mondiales) : Présente les taux de prévalence de différents troubles de la santé mentale répartis par pays, par année et par données démographiques.
#
# Approbation de Cartes de Crédit : Contient des données financières anonymisées de clients (revenus, antécédents de crédit, dettes) associées à la décision finale de la banque (approuvé ou rejeté).
